# %% [markdown]
# # итоговое задание по модулю 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue              original_title  \
# 79    tt1666801    8500000   43528634                    The DUFF
# 1219  tt1204975   28000000  134402450                  Last Vegas
# 1115  tt0285823   29000000   98185582  Once Upon a Time in Mexico
# 1060  tt1712170   45000000   30353232                  Alex Cross
# 996   tt1077368  150000000  245527149                Dark Shadows
#
#                                                    cast          director  \
# 79    Mae Whitman|Robbie Amell|Bella Thorne|Bianca A...        Ari Sandel
# 1219  Robert De Niro|Morgan Freeman|Michael Douglas|...    Jon Turteltaub
# 1115  Antonio Banderas|Salma Hayek|Johnny Depp|Eva M...  Robert Rodriguez
# 1060  Tyler Perry|Rachel Nichols|Jean Reno|Matthew F...         Rob Cohen
# 996   Johnny Depp|Michelle Pfeiffer|Helena Bonham Ca...        Tim Burton
#
#                                                 tagline  \
# 79    You either know one, you have one, or you are ...
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

data.info()  # проверяем, есть ли в сете нулевые значения.

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# data = pd.to_datetime(data['release_date'])
# df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %%
# также нужно проверить сет на наличие дублирующихся значений

data.drop_duplicates()

# видно что кол-во строчек не изменилось
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data['profit'] = data['revenue'] - data['budget'] # добавим столбец со значениями прибыли

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '723. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:

data[data.budget == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit
# 723           6.3          2011  641683000

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения
data.sort_values(by='budget', ascending=False).head(3)
# Out:
#         imdb_id     budget     revenue  \
# 723   tt1298650  380000000  1021683000
# 1669  tt0449088  300000000   961000000
# 14    tt2395427  280000000  1405035767
#
#                                    original_title  \
# 723   Pirates of the Caribbean: On Stranger Tides
# 1669     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
#
#                                                    cast        director  \
# 723   Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...    Rob Marshall
# 1669  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...  Gore Verbinski
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...     Joss Whedon
#
#                                              tagline  \
# 723                      Live Forever Or Die Trying.
# 1669  At the end of the world, the adventure begins.
# 14                               A New Age Has Come.
#
#                                                overview  runtime  \
# ...

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = '1157. Gods and Generals (tt0279111)'

# %%
data[data.runtime == data.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit
# 1157           5.8          2003 -43076064

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '768. Winnie the Pooh (tt1449283)'

# %%
data[data.runtime == data.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit
# 768    4/13/2011           6.8          2011 -15540000

# %%
data.sort_values(by='runtime', ascending=False)

# из этой отсортированной таблицы можно взять ответы на вопросы №2 и №3
# Out:
#         imdb_id     budget     revenue  \
# 1157  tt0279111   56000000    12923936
# 1081  tt0167260   94000000  1118888979
# 1736  tt0462322   67000000    25037897
# 1336  tt0360717  207000000   550000000
# 504   tt0213149  140000000   449220945
# ...         ...        ...         ...
# 1408  tt0361089   35000000    19478106
# 1626  tt0299172  110000000   103951461
# 1097  tt0283426   20000000   135680000
# 930   tt0280030   20000000   109862682
# 768   tt1449283   30000000    14460000
#
#                                      original_title  \
# 1157                              Gods and Generals
# 1081  The Lord of the Rings: The Return of the King
# 1736                                     Grindhouse
# 1336                                      King Kong
# 504                                    Pearl Harbor
# ...                                             ...
# 1408                                        Valiant
# 1626                              Home on the Range
# ...

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '109.658549' # что приближенно будем считать 110мин.

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#              profit
# count  1.889000e+03
# mean   1.010545e+08
# std    1.830733e+08
# min   -1.657101e+08
# 25%    5.000000e+06
# 50%    4.400041e+07
# 75%    1.201842e+08
# max    2.544506e+09

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107'

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '239. Avatar (tt0499549)'

# %%
data.sort_values(by='profit', ascending=False) # Данную сортировку будем использовать для ответов на 6 и 7 вопросы
# Out:
#         imdb_id     budget     revenue                original_title  \
# 239   tt0499549  237000000  2781505847                        Avatar
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 0     tt0369610  150000000  1513528810                Jurassic World
# 4     tt2820852  190000000  1506249360                     Furious 7
# 970   tt0848228  220000000  1519557910                  The Avengers
# ...         ...        ...         ...                           ...
# 1464  tt0424095  149000000    64459316                  Flushed Away
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 1616  tt0318974  145000000    25819961                     The Alamo
# 1245  tt1210819  255000000    89289910               The Lone Ranger
#
#                                                    cast  \
# 239   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '1245. The Lone Ranger (tt1210819)'

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478'

# %%
len(data[data.revenue > data.budget])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '599. The Dark Knight (tt0468569)'

# %%
data[data.release_year == 2008].sort_values(by='revenue', ascending=False).head(1)
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '1245. The Lone Ranger (tt1210819)'

# %%
data.loc[(data.release_year >= 2012) & (data.release_year <= 2014)].sort_values(by='profit').head(1)
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = 'Drama'

# %%
data_to_explode = data.copy()                                       # -- создаем копию датасета
data_to_explode['genres'] = data_to_explode.genres.str.split('|')   # -- разбиваем на одиночные жанры
data_to_explode = data_to_explode.explode('genres')
data_to_explode.genres.value_counts().head(1)
# Out:
# Drama    782
# Name: genres, dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama = FAIL'

# %%
# -- возьмем часть кода из предыдущего вопроса, а именно data_to_explode

data12 = data.copy()
data12 = data12[data12['profit'] > 0]
data12['genres'] = data12.genres.str.split('|')
data12.explode('genres').groupby(['genres'])['imdb_id'].count().sort_values(ascending=False).head(1)

#-- Зафейлил этот вопрос, т.к. в самом начале фильтровал по profit>mean()
# Out:
# genres
# Drama    560
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson'

# %%
director_sum = data.groupby(['director']).revenue.sum().sort_values(ascending=False).head(1)
director_sum
# Out:
# director
# Peter Jackson    6490593685
# Name: revenue, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Robert Rodriguez'

# %%
data14 = data.copy()
data14 = data14[data14.genres.str.contains('Action', na=False)]
data14['director'] = data14.director.str.split('|')
data14.explode('director').groupby(['director'])['imdb_id'].count().sort_values(ascending=False).head(1)
# Out:
# director
# Robert Rodriguez    9
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = 'Chris Hemsworth'

# %%
data2012 = data.copy()
data2012 = data2012[data2012['release_year'] == 2012]
data2012['cast'] = data2012.cast.str.split('|')
data2012 = data2012.explode('cast')
data_pivot = data2012.pivot_table(index='cast', values='revenue', aggfunc='sum')
data_pivot.sort_values(by='revenue', ascending=False).head(1)
# Out:
#                     revenue
# cast
# Chris Hemsworth  2027450773

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = 'Matt Damon'

# %%
data16 = data.copy()
data16 = data16[data16['budget'] > data16['budget'].mean()]
data16['cast'] = data16.cast.str.split('|')
data16.explode('cast').groupby(['cast'])['imdb_id'].count().sort_values(ascending=False).head(1)
# Out:
# cast
# Matt Damon    18
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = 'Action'

# %%
data17 = data[data['cast'].str.contains('Nicolas Cage', na=False)] # -- ищем те фильмы, в который снимался Николас
data17.genres.str.split('|').explode('genres').value_counts().head(1) # -- разбиваем ячейки жанров на отдельные и считаем
# Out:
# Action    17
# Name: genres, dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '925. K-19: The Widowmaker (tt0267626)'

# %%
data[data['production_companies'].str.contains('paramount pictures', na=False, case=False)].sort_values(by='profit').head(1)
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 925  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 925  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_average  release_year    profit
# 925           6.0          2002 -64831034

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '2015'

# %%
data.groupby(by='release_year').revenue.sum().sort_values(ascending=False).head(1)
# Out:
# release_year
# 2015    25449202382
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '2014'

# %%
data20 = data[data['production_companies'].str.contains('Warner Bros')]
data20_pivot = data20.pivot_table(index='release_year', values='profit', aggfunc='sum').sort_values(by='profit',ascending=False)
data20_pivot.head(1)
# Out:
#                   profit
# release_year
# 2014          2295464519

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '9 - September'

# %%
data.release_date = pd.to_datetime(data.release_date)
data.release_date
data['release_month'] = data.release_date.dt.month
data.release_date.dt.month.value_counts().sort_values(ascending=False).head(1)
# Out:
# 9    227
# Name: release_date, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '450'

# %%
data22 = data.copy()
data[(data['release_month'] == 6)|(data['release_month'] == 7)|(data['release_month'] == 8)]['imdb_id'].count()
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = 'Peter Jackson'

# %%
data23 = data.copy()
data23 = data23[data23['release_month'].isin(['12', '1', '2'])]
data23['director'] = data23.director.str.split('|')
data23 = data23.explode('director')
data23.groupby(['director'])['imdb_id'].count().sort_values(ascending=False).head(1)
# Out:
# director
# Peter Jackson    7
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = 'Universal Pictures'   # -- FAILED

# %%
data24 = data.copy()
data24['len_title'] = data24.original_title.str.len()
data24['production_companies'] = data24.production_companies.str.split('|')
data24 = data24.explode('production_companies')
data24.groupby(['production_companies'])['len_title'].count().sort_values(ascending=False).head(1)
# Out:
# production_companies
# Universal Pictures    173
# Name: len_title, dtype: int64

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = 'Universal Pictures'    # -- FAILED

# %%
data25 = data.copy()
data25['len_overview'] = data25.overview.str.count(' ') + 1  # -- считаем что в предложении слова разделены пробелами и кол-во слов на 1 больше
data25 = data25[data25['len_overview'] > data25['len_overview'].mean()]
data25['production_companies'] = data25.production_companies.str.split('|')
data25 = data25.explode('production_companies')
data25.groupby('production_companies')['len_overview'].count().sort_values(ascending=False).head(1)
# Out:
# production_companies
# Universal Pictures    95
# Name: len_overview, dtype: int64

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = 'The Dark Knight'

# %%
rate_99 = np.percentile(data.vote_average, 99)
data[data.vote_average >= rate_99].sort_values(by='vote_average', ascending=False)
# Out:
#         imdb_id     budget     revenue  \
# 599   tt0468569  185000000  1001921825
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 125   tt2084970   14000000   233555708
# 370   tt1375666  160000000   825500000
# 1191  tt2024544   20000000   187000000
# 1183  tt0993846  100000000   392000694
# 1081  tt0167260   94000000  1118888979
# 872   tt0253474   35000000   120072577
# 1800  tt0209144    9000000    39723096
# 119   tt2015381  170000000   773312399
# 138   tt2278388   30000000   174600318
# 128   tt2267998   61000000   369330363
# 283   tt0485947   47000000     3547209
# 1688  tt0469494   25000000    76181545
# 1563  tt0338013   20000000    72258126
# 1444  tt0482571   40000000   109676311
# 1213  tt0790636    5000000    55198285
# 1205  tt1392214   46000000   122126687
# 124   tt2245084  165000000   652105443
# 1188  tt1798709   23000000    47351251
# 316   tt1187043    9000000    70000000
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '723. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '1157. Gods and Generals (tt0279111)',
#  '3': '768. Winnie the Pooh (tt1449283)',
#  '4': '109.658549',
#  '5': '107',
#  '6': '239. Avatar (tt0499549)',
#  '7': '1245. The Lone Ranger (tt1210819)',
#  '8': '1478',
#  '9': '599. The Dark Knight (tt0468569)',
#  '10': '1245. The Lone Ranger (tt1210819)',
#  '11': 'Drama',
#  '12': 'Drama = FAIL',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '18': '925. K-19: The Widowmaker (tt0267626)',
#  '19': '2015',
#  '20': '2014',
#  '21': '9 - September',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '24': 'Universal Pictures',
#  '25': 'Universal Pictures',
#  '26': 'The Dark Knight'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 26
